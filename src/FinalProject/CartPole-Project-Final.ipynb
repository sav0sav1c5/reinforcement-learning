# %% [markdown]
# # **Project:** Cart Pole

# %% [markdown]
# ## **Problem Description**

# %% [markdown]
# The inverted pendulum problem (cart-pole problem) is often used as one of the fundamental examples in reinforcement learning. It consists of a rod attached by an unmovable joint to a cart that moves linearly along a track, without friction. The center of mass of the rod is located above its pivot point. The goal is to maintain the system balanced by applying appropriate forces to the cart itself. This physical system, due to its nonlinear dynamics and unstable operating point, presents a challenge in the control domain. In this regard, the idea of this final project is to apply one of the reinforcement learning methods to control such a physical system. The schematic of this problem setup is shown in Figure 1.
#
# <div align="center">
#
# ![alt text](cart_pole-1.svg)
#
# </div>
#
# The inverted pendulum can be modeled by a system of nonlinear equations:
#
# $$\ddot{\theta} = \frac{Mg \sin \theta - \cos \theta(F + ml \dot{\theta}^2 \sin \theta)}{(1 + k)Ml - ml \cos^2 \theta}$$
#
# $$\ddot{x} = \frac{mg \sin \theta \cos \theta - (1 + k)(F + ml \dot{\theta}^2 \sin \theta)}{m \cos^2 \theta - (1 + k)M}$$
#
# *Equations are taken from https://sharpneat.sourceforge.io/research/cart-pole/cart-pole-equations.html*
#
# **Parameters:**
# - **m** - mass of the rod (100g)
# - **M** - total mass of rod and cart (1.1kg)
# - **l** - length of the rod (0.5m)
# - **g** - gravitational constant (no suggested value)
# - **θ** - angle between rod and vertical axis
# - **x** - position
# - **F** - force (F ∈ [-10N, 10N])
# - **k** - constant related to rod's moment of inertia (k = 0; k = 1/3; k = 1)
#
# *Values in parentheses are suggested values you can use in implementation.*
#
# In compact form, the model can also be written as:
#
# $$\ddot{\theta} = f_\theta(x, \dot{x}, \theta, \dot{\theta}, F)$$
# $$\ddot{x} = f_x(x, \dot{x}, \theta, \dot{\theta}, F)$$
#
# where $f_\theta$ and $f_x$ are nonlinear functions.
#
# ---
#
# **Converting Mathematical Model to MDP**
#
# To control such a model using methods we've learned in this course, we need to convert it to a suitable form. Although Markov Decision Processes can be generalized to cases where time flows continuously, we won't deal with that here. Instead, we'll convert the given model to a form equivalent to a Markov Decision Process: the next state and reward are functions of the current state and applied action, i.e.:
#
# $$s^+ = f(s, a)$$
# $$r = h(s, a)$$
#
# Although it may not be obvious, the first step is to reduce the order of the system given by equations (2). By introducing substitutions:
#
# $$z_1 = x$$
#
# $$z_2 = \dot{x}$$
#
# $$z_3 = \theta$$
#
# $$z_4 = \dot{\theta}$$
#
# and differentiating the left side of each equation with respect to time, we get a mathematical model in state space form:
#
# $$\dot{z_1} = z_2$$
#
# $$\dot{z_2} = f_x(z, F)$$
#
# $$\dot{z_3} = z_4$$
#
# $$\dot{z_4} = f_\theta(z, F)$$
#
# where $z = (z_1, z_2, z_3, z_4)$. In other words, all state variables are enumerated in z.
#
# The second step is discretization. For this task, we'll choose Euler discretization, i.e., numerical integration with left rectangles, because for nonlinear models it's sometimes simply not possible to apply anything else. By introducing the substitution $\dot{z_i} = \frac{1}{T}(z_i^+ - z_i)$, i = 1,2,3,4, which corresponds to the first derivative approximation in forward differencing, we get the equations:
#
# $$z_1^+ = z_1 + T z_2$$
#
# $$z_2^+ = z_2 + T f_x(z, F)$$
#
# $$z_3^+ = z_3 + T z_4$$
#
# $$z_4^+ = z_4 + T f_\theta(z, F)$$
#
# The physical system is now converted to MDP form, with the detail that we now have a state vector $z = (z_1, z_2, z_3, z_4)$. On the other hand, action $a$ is nothing other than the force $F$ applied to the cart at a given moment in time. The action is also discrete and bounded.
#
# ---
#
# **Reward Formation**
#
# The question of reward formation is essential, i.e., the function $h$ in equation $r = h(s, a)$ of the deterministic MDP. In this section, we offer several suggestions for reward function formation:
#
# **Option 1:**
# $$r = \begin{cases}
# |\theta|^\alpha & \text{if } \theta < 60° \\
# -1000 & \text{if } \theta \geq 60°
# \end{cases}$$
#
# **Option 2:**
# $$r = \begin{cases}
# 0 & \text{if } \theta = ±90° \\
# -100 & \text{if } \theta \neq ±90°
# \end{cases}$$
#
# **Option 3:**
# $$r = \begin{cases}
# 1 & \text{if } \theta = ±90° \\
# 0 & \text{if } \theta \neq ±90°
# \end{cases}$$
#
# The last suggestion is given following the predefined Gymnasium environment for the inverted pendulum. At the following hyperlinks, you can find general instructions for using Gymnasium environments, training agents, and using the cart-pole environment itself.
#
# **Useful Links:**
# - [Using environments](https://gymnasium.farama.org/)
# - [Agent training example](https://stable-baselines3.readthedocs.io/)
# - [Cart-pole environment](https://gymnasium.farama.org/environments/classic_control/cart_pole/)
#
# We note that using the predefined environment is not mandatory; we only suggest it as an option. Although we would ideally greatly appreciate you implementing the environment and solution yourself, we offer Gymnasium as a (potentially) facilitating circumstance. In this regard, the decision whether to use it will not affect the number of points earned on this final task.

# %% [markdown]
# ##### **Note:** Version on Serbian

# %% [markdown]
# **Opis problema**
#
# Problem inverznog klatna (eng. **cart-pole problem**) često se koristi kao jedan od osnovih primera u učenju potkrepljenjem. To je šipka je pričvršćena nepokretnim zglobom za kolica koja se kreću pravolinijski duž pruge, bez trenja. Centar mase šipke nalazi se iznad njene pivot tačke. Cilj je održavati sistem balansiranim, i to primenom adekvatnih sila na sama kolica. Ovakav fizički sistem, zbog svoje nelinearne dinamike i nestabilne radne tačke, predstavlja izazov u domenu upravljanja. S tim u vezi, ideja ovog završnog domaćeg zadatka je da se primeni neka od metoda učenja potkrepljenjem za upravljanje ovakvim fizičkim sistemom.
#
# <div align="center">
#
# ![alt text](cart_pole-1.svg)
#
# </div>
#
# **Slika 1:** Prikaz modela inverznog klatna.
#
# ---
#
# **Matematički model**
#
# Inverzno klatno može da se modeluje sistemom nelinearnih jednačina:
#
# $$\ddot{\theta} = \frac{Mg \sin \theta - \cos \theta(F + ml \dot{\theta}^2 \sin \theta)}{(1 + k)Ml - ml \cos^2 \theta}$$
#
# $$\ddot{x} = \frac{mg \sin \theta \cos \theta - (1 + k)(F + ml \dot{\theta}^2 \sin \theta)}{m \cos^2 \theta - (1 + k)M}$$
#
# *Jednačine su preuzete sa https://sharpneat.sourceforge.io/research/cart-pole/cart-pole-equations.html*
#
# **Parametri modela:**
# - **m** - masa štapa (100g)
# - **M** - ukupna masa štapa i kolica (1.1kg)
# - **l** - dužina šipke (0.5m)
# - **g** - gravitaciona konstanta (nema predložene vrednosti)
# - **θ** - ugao između šipke i vertikalne ose
# - **x** - pozicija
# - **F** - sila (F ∈ [-10N, 10N])
# - **k** - konstanta vezana za moment inercije štapa (k = 0; k = 1/3; k = 1)
#
# U sažetoj formi, model možemo zapisati i u obliku:
#
# $$\ddot{\theta} = f_\theta (x, \dot{x}, \theta, \dot{\theta}, F)$$
# $$\ddot{x} = f_x(x, \dot{x}, \theta, \dot{\theta}, F)$$
#
# pri čemu su $f_\theta$ i $f_x$ nelinearne funkcije.
#
# ---
#
# **Prevođenje matematičkog modela u MPO**
#
# Da bismo ovakvim modelom mogli da upravljamo nekim od metoda sa kojima smo se upoznali na ovom predmetu, potrebno je da ga prevedemo u pogodnu formu. Premda se Markovljevi procesi odlučivanja mogu uopštiti i na slučajeve kada vreme teče kontinualno, mi se time ovde nećemo baviti. Umesto toga, dati model ćemo prevesti u formu koja je ekvivalentna Markovljevom procesu odlučivanja: naredno stanje i nagrada su funkcije tekućeg stanja i primenjene akcije, odnosno:
#
# $$s^+ = f(s, a)$$
# $$r = h(s, a)$$
#
# **Korak 1: Snižavanje reda sistema**
#
# Uvođenjem smena:
# $$z_1 = x$$
# $$z_2 = \dot{x}$$
# $$z_3 = \theta$$
# $$z_4 = \dot{\theta}$$
#
# i diferenciranjem po vremenu leve strane svake jednačine, dobijamo matematički model u prostoru stanja u obliku:
#
# $$\dot{z_1} = z_2$$
# $$\dot{z_2} = f_x(z, F)$$
# $$\dot{z_3} = z_4$$
# $$\dot{z_4} = f_\theta(z, F)$$
#
# pri čemu je $z = (z_1, z_2, z_3, z_4)$.
#
# **Korak 2: Diskretizacija (Euler metoda)**
#
# Za potrebe ovog zadatka, izabraćemo Euler diskretizaciju, tj numeričku integraciju levim pravougaonicima. Uvođenjem smene $\dot{z_i} = \frac{1}{T}(z_i^+ - z_i)$, dobijamo jednačine:
#
# $$z_1^+ = z_1 + T z_2$$
# $$z_2^+ = z_2 + T f_x(z, F)$$
# $$z_3^+ = z_3 + T z_4$$
# $$z_4^+ = z_4 + T f_\theta(z, F)$$
#
# Fizički sistem je sada preveden u formu MPO, sa detaljem da sada imamo **vektor stanja** $z = (z_1, z_2, z_3, z_4)$. S druge strane **akcija** $a$ je ništa drugo nego sila $F$ koja se u datom trenutku vremena primenjuje na kolica. Akcija je takođe diskretna i ograničena veličina.
#
# ---
#
# **Formiranje nagrade**
#
# Neizostavno je i pitanje načina formiranja nagrade, odnosno funkcije $h$ u jednačini $r = h(s, a)$ determinističkog MPO. Evo nekoliko predloga za način formiranja funkcije nagrade:
#
# **1. Nagrada bazirana na uglu (sa eksponentom):**
# $$r = \begin{cases}
# |\theta|^\alpha & \text{ako } \theta < 60° \\
# -1000 & \text{ako } \theta \geq 60°
# \end{cases}$$
#
# **2. Binarna nagrada (klasična):**
# $$r = \begin{cases}
# 0 & \text{ako } \theta = ±90° \\
# -100 & \text{ako } \theta \neq ±90°
# \end{cases}$$
#
# **3. Pozitivna nagrada (Gymnasium stil):**
# $$r = \begin{cases}
# 1 & \text{ako } \theta = ±90° \\
# 0 & \text{ako } \theta \neq ±90°
# \end{cases}$$
#
# Poslednji predlog je dat po uzoru na predefinisano **Gymnasium** okruženje za inverzno klatno.
#
# **Korisni linkovi za Gymnasium:**
# - [Korišćenje okruženja](https://gymnasium.farama.org/)
# - [Primer treniranja agenta](https://gymnasium.farama.org/tutorials/)
# - [Cart-pole okruženje](https://gymnasium.farama.org/environments/classic_control/cart_pole/)
#
# **Napomena:** Korišćenje predefinisanog okruženja nije obavezno, ovde ga samo predlažemo kao opciju. Iako bismo u idealnom slučaju izuzetno cenili da sami implementirate okruženje i rešenje, Gymnasium nudimo kao (potencijalno) olakšavajuću okolnost. S tim u vezi, odluka o tome da li ga koristite neće uticati na broj ostvarenih bodova na ovom završnom zadatku.
#
# ---
#
# **Zadaci za samostalan rad**
#
# 1. **Diskretizacija matematičkog modela u prostoru stanja**
#    - U slučaju da koristite Gymnasium, ovaj korak nije potreban.
#
# 2. **Definisanje prostora akcija**
#    - Napominjemo da prostor akcija treba da bude diskretan i ograničen.
#    - U slučaju da koristite Gymnasium, prostor akcija je već predefinisan.
#
# 3. **Izbor načina formiranja nagrade**
#    - Nije obavezno da izaberete neki od datih predloga
#    - Slobodno osmislite originalan način formiranja nagrade.
#
# 4. **Treniranje agenta pomoću Q-Learning ili SARSA**
#
# 5. **Simulacija okruženja i prikaz dobijenih rezultata**
#    - Ukoliko se ne služite Gymnasium okruženjem, nije obavezno da pravite nikakvu vizualizaciju.

# %% [markdown]
# ## **Assignment**

# %% [markdown]
# Tasks for independent work:
#
# 1. **Perform discretization of the mathematical model in state space.** *If using Gymnasium, this step is not necessary.*
#
# 2. **Define the action space.** Note that the action space should be discrete and bounded. *If using Gymnasium, the action space is already predefined.*
#
# 3. **Choose a method for reward formation.** It's not mandatory to choose one of the given suggestions; feel free to devise an original way of forming rewards.
#
# 4. **Train an agent using Q-Learning or SARSA.**
#
# 5. **Simulate the environment and display the obtained results.** If you're not using the Gymnasium environment, visualization is not mandatory.

# %% [markdown]
# ## **Solution:** Implemented Environment

# %% [markdown]
# This solution is implemented without using external libraries and it contains my implementation of Cart Pole problem environment.

# %% [markdown]
# #### Basic imports

# %%
import math
import random
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from itertools import product

# %% [markdown]
# ### **Implement:** `Cart-Pole Model`

# %% [markdown]
# **Task 1:** **Perform discretization of the mathematical model in state space.** *If using Gymnasium, this step is not necessary.*

# %%
class CartPoleModel:
    """
    Physics model of Cart-Pole system.
    Simulates how the cart and pole move based on forces applied.
    """

    def __init__(self, T = 0.02, m = 0.1, M = 1.1, l = 0.5, g = 9.81, k = 1/3):
        """
        Initialize physics model of Cart-Pole system.

        Parameters:
            T: time step (seconds)
            m: mass of the pole (kg)
            M: mass of the cart (kg)
            l: length of the pole (meters)
            g: gravitational acceleration (m/s²)
            k: moment of inertia constant
        """
        self.T = T
        self.m = m
        self.M = M
        self.l = l
        self.g = g
        self.k = k

    def f_x(self, z, F):
        """
        Calculates horizontal acceleration of the cart by using one of given nonlinear equations.
        """
        _, _, theta, theta_dot = z
        sin_theta = math.sin(theta)
        cos_theta = math.cos(theta)
        numerator = (self.m * self.g * sin_theta * cos_theta - (1 + self.k) * (F + self.m * self.l * theta_dot**2 * sin_theta))
        denominator = (self.m * cos_theta**2 - (1 + self.k) * self.M)

        return numerator / denominator if abs(denominator) > 1e-10 else 0

    def f_theta(self, z, F):
        """
        Calculate angular acceleration of the pole by by using one of given nonlinear equations.
        """
        _, _, theta, theta_dot = z
        sin_theta = math.sin(theta)
        cos_theta = math.cos(theta)
        numerator = (self.M * self.g * sin_theta - cos_theta * (F + self.m * self.l * theta_dot**2 * sin_theta))
        denominator = ((1 + self.k) * self.M * self.l - self.m * self.l * cos_theta**2)

        return numerator / denominator if abs(denominator) > 1e-10 else 0

    def next_state(self, z, force):
        """
        Calculate next state using Euler integration.
        """
        z_next = np.zeros(4)

        z_next[0] = z[0] + self.T * z[1]                        # Update position
        z_next[1] = z[1] + self.T * self.f_x(z, force)          # Update velocity
        z_next[2] = z[2] + self.T * z[3]                        # Update angle
        z_next[3] = z[3] + self.T * self.f_theta(z, force)      # Update angle velocity

        return z_next

# %% [markdown]
# ### **Implement:** `Cart-Pole State Discretizer`

# %%
class CartPoleStateDiscretizer:
    """
    Converts Cart-Pole continuous state space to discrete states (bins) for Q-Learning.
    So we take each state variable and split them in provided number of bins.
    """

    def __init__(self, bins=(10, 10, 10, 10), limits=None):
        """
        Initialize Cart-Pole state discretizer.

        Parameters:
            bins: number of bins for each state variable (x, x_dot, theta, theta_dot)
            limits: tuple of limits for each state variable
        """
        self.bins = bins

        if limits is not None:
            # Use provided limits for each state variable
            self.x_limit = limits[0]
            self.x_dot_limit = limits[1]
            self.theta_limit = limits[2]
            self.theta_dot_limit = limits[3]
        else:
            # Default limits for Cart-Pole problem
            self.x_limit = (-2.4, 2.4)
            self.x_dot_limit = (-3.0, 3.0)
            self.theta_limit = (-0.20944, 0.20944)
            self.theta_dot_limit = (-2.0, 2.0)

    def discretize_state(self, state):
        """
        Convert continuous state into discrete bins.
            np.clip() - If values is outside of range, set it on the boundary (limit value)
            np.digitize - Finds which bin each value belongs to, returns 1-indexed, so we
                          subtract 1, to get 0-indexed)
        """
        state = tuple(state)
        x, x_dot, theta, theta_dot = state

        # Clip state variables to their limits
        x = np.clip(x, self.x_limit[0], self.x_limit[1])
        x_dot = np.clip(x_dot, self.x_dot_limit[0], self.x_dot_limit[1])
        theta = np.clip(theta, self.theta_limit[0], self.theta_limit[1])
        theta_dot = np.clip(theta_dot, self.theta_dot_limit[0], self.theta_dot_limit[1])

        # Create bin edges for each state variable
        x_bins = np.linspace(self.x_limit[0], self.x_limit[1], self.bins[0] + 1)
        x_dot_bins = np.linspace(self.x_dot_limit[0], self.x_dot_limit[1], self.bins[1] + 1)
        theta_bins = np.linspace(self.theta_limit[0], self.theta_limit[1], self.bins[2] + 1)
        theta_dot_bins = np.linspace(self.theta_dot_limit[0], self.theta_dot_limit[1], self.bins[3] + 1)

        # Find which bin each state variable falls into (discretize each dimension)
        x_discrete = np.digitize(x, x_bins) - 1
        x_dot_discrete = np.digitize(x_dot, x_dot_bins) - 1
        theta_discrete = np.digitize(theta, theta_bins) - 1
        theta_dot_discrete = np.digitize(theta_dot, theta_dot_bins) - 1

        # Ensure indices (indexes) are within valid range (handle edge cases)
        x_discrete = max(0, min(x_discrete, self.bins[0] - 1))
        x_dot_discrete = max(0, min(x_dot_discrete, self.bins[1] - 1))
        theta_discrete = max(0, min(theta_discrete, self.bins[2] - 1))
        theta_dot_discrete = max(0, min(theta_dot_discrete, self.bins[3] - 1))

        return (x_discrete, x_dot_discrete, theta_discrete, theta_dot_discrete)

# %% [markdown]
# **Note:**
# - `state = tuple(state)`: state needs to be hashable

# %% [markdown]
# ### **Implement:** `Cart-Pole Action Space`

# %% [markdown]
# **Task 2:** **Define the action space.** Note that the action space should be discrete and bounded. *If using Gymnasium, the action space is already predefined.*

# %%
class ActionSpace:
    """
    Defines action space with actions that agent can take.
    Agent take some action ---> Agent apply some force
    """

    def __init__(self, actions_type = 'binary', max_force: float = 10.0):
        """
        Initialize action space for Cart-Pole system.

        Parameters:
            actions_type: 'binary' | 'ternary' | 'multi'
            max_force: maximum force that can be applied
        """
        self.actions_type = actions_type
        self.max_force = max_force

        # Defined action space, discrete and bounded (with limits), based on chosen actions_type
        if actions_type == 'binary':
            self.action_num = 2
            self.actions = [-max_force, +max_force]
            self.action_names = ['Left (-10)', 'Right (+10)']

        elif actions_type == 'ternary':
            self.action_num = 3
            self.actions = [-max_force, 0.0, +max_force]
            self.action_names = ['Left (-10)', 'No Force (0)', 'Right (+10)']

        elif actions_type == 'multi':
            self.action_num = 5
            self.actions = [-max_force, -max_force/2, 0.0, +max_force/2, +max_force]
            self.action_names = ['Strong Left (-10)',
                                 'Weak Left (-10)',
                                 'No Force (0)',
                                 'Weak Right (+10)',
                                 'Strong Right (+10)']

    def get_random_action(self):
        """
        Get a random action index for exploration of environment.
        """
        return np.random.randint(0, self.action_num)

    def get_force(self, action_idx: int):
        """
        Convert a action index in force value and description.
        """
        if 0 <= action_idx < self.action_num:
            force = self.actions[action_idx]
            force_description = self.action_names[action_idx]
            return force, force_description
        else:
            raise ValueError(f"Invalid action index: {action_idx}")

# %% [markdown]
# ### **Implement:** `Cart-Pole Reward Formation Functions`

# %% [markdown]
# **Task 3:** **Choose a method for reward formation.** It's not mandatory to choose one of the given suggestions; feel free to devise an original way of forming rewards.

# %%
class RewardFunction:
    """
    Defines reward formation function that return reward agent received after taken action.
    """

    def __init__(self, reward_type = 'angle_based', alpha = 2.0, terminal_theta = 0.20944):
        """
        Initialize reward formation function for Cart-Pole system.

        Parameters:
            reward_type: 'angle_based' | 'binary' | 'gym_based'
            alpha: exponent parameter for first reward function
            terminal_theta: terminal angle that will flag that state is terminal (task failed)
        """
        self.reward_type = reward_type
        self.alpha = alpha
        self.terminal_theta = terminal_theta

    def angle_based_reward(self, theta: float):
        """
        Angle-based reward function. Rewards smaller deviations from vertical.
        """
        theta_degree = math.degrees(theta)
        if abs(theta_degree) < 60:
            return -abs(theta_degree)**self.alpha  # Based on angle between pole and vertical axis
        else:
            return -1000.0  # Penalty is pole cross angle limit

    def binary_reward(self, theta: float):
        """
        Binary reward function. Anti-reward (penalty) strategy.
        """
        if abs(theta) >= self.terminal_theta:
            return -100.0  # Penalty for terminal state
        else:
            return 0.0  # No reward for non-terminal states

    def gym_based_reward(self):
        """
        Gymnasium type binary reward function. Agent is rewarded if pole is not down.
        """
        return 1.0  # Reward for surviving


    def get_reward(self, theta: float = None):
        """
        Get reward by reward function of chosen reward type.
        Note: For gym_based, theta is not used.
        """
        if self.reward_type == 'angle_based':
            if theta is None:
                raise ValueError("Theta required for angle_based reward.")
            reward = self.angle_based_reward(theta)
        elif self.reward_type == 'binary':
            if theta is None:
                raise ValueError("Theta required for binary reward.")
            reward = self.binary_reward(theta)
        elif self.reward_type == 'gym_based':
            reward = self.gym_based_reward()  # No dependency on theta
        else:
            raise ValueError("Unknown reward function type.")

        return reward

# %% [markdown]
# ### **Implement:** `Cart-Pole Q-Learning Agent`

# %% [markdown]
# **Task 4:** **Train an agent using Q-Learning or SARSA.**

# %%
class QLearningAgent:
    """
    Q-Learning agent for solving Cart-Pole problem.
    """

    def __init__(self, action_size, gamma = 0.95, epsilon = 1.0, epsilon_min = 0.01,
                 epsilon_decay = 0.995, alpha = 0.1):
        """
        Initialize Q-Learning agent.

        Parameters:
            action_size: ActionSpace size (number of actions)
            gamma: discount factor
            epsilon: initial exploration rate
            epsilon_min: minimum epsilon value
            epsilon_decay: decay rate for epsilon
            alpha: learning rate
        """
        self.action_size = action_size
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.alpha = alpha

        self.q_table = defaultdict(lambda: np.zeros(action_size))

        self.total_rewards = []
        self.total_steps = []

    def get_action(self, state, training_active = True):
        """
        Choose action using epsilon-greedy policy.
        """
        if training_active and np.random.random() < self.epsilon:
            # Exploration: choose random action
            return np.random.randint(0, self.action_size)
        else:
            # Exploitation: choose best action based on Q-values
            return np.argmax(self.q_table[state])

    def decay_epsilon(self):
        """
        Decay (lovers) exploration rate after each episode.
        """
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

    def update_q_table(self, state, action, reward, next_state, terminal):
        """
        Update Q-table using Q-Learning update formula.
        Q(s,a) <- Q(s,a) + alpha * (r + gamma*max_a' Q(s',a')*(1 - terminal) - Q(s,a))

        If terminal: td_target = reward (no bootstrap).
        """
        if terminal:
            td_target = reward
        else:
            best_next = np.max(self.q_table[next_state])
            td_target = reward + self.gamma * best_next

        td_error = td_target - self.q_table[state][action]

        self.q_table[state][action] += self.alpha * td_error

# %% [markdown]
# ### **Implement:** `Train Q-Learning Agent Method`

# %%
def train_agent(environment, state_discretizer, agent, episodes_number, max_steps=500):
    """
    The main function for training the Q-learning agent.

    Parameters:
        environment: The environment of the cart and stick
        state_discretizer: State discretizer
        agent: Q-learning agent
        episodes_number: Number of training episodes
        max_steps: Maximum steps per episode
    """
    training_rewards = []
    training_steps = []

    for episode in range(episodes_number):
        # Reset environment to initial state
        state = environment.reset()
        state_discrete = state_discretizer.discretize_state(state)

        episode_reward = 0
        episode_steps = 0
        terminal = False

        # Run episode until terminal state or max steps reached
        while not terminal and episode_steps < max_steps:
            # Agent chooses action
            action = agent.get_action(state_discrete)

            # Execute action in environment
            next_state, reward, terminal = environment.step(action)

            # Discretize next state
            next_state_discrete = state_discretizer.discretize_state(next_state)

            # Update Q-table with experience
            agent.update_q_table(state_discrete, action, reward, next_state_discrete, terminal)

            # Update current state
            state_discrete = next_state_discrete

            # Accumulate episode statistics
            episode_reward += reward
            episode_steps += 1

        # Decay exploration rate
        agent.decay_epsilon()

        # Store episode results
        training_rewards.append(episode_reward)
        training_steps.append(episode_steps)

    return training_rewards, training_steps

# %% [markdown]
# ### **Implement:** `Cart-Pole Environment`

# %% [markdown]
# **Task 5:** **Simulate the environment and display the obtained results.** If you're not using the Gymnasium environment, visualization is not mandatory.

# %%
class CartPoleEnvironment:
    """
    Cart-Pole environment that combines physics model, action space, and reward function.
    Provides interface for RL agent to interact with the environment.
    """

    def __init__(self, model, action_space, reward_function):
        """
        Initialize Cart-Pole system Environment.

        Parameters:
            model: CartPoleModel instance for physics simulation
            action_space: ActionSpace instance defining available actions
            reward_function: RewardFunction instance for calculating rewards
        """
        self.model = model
        self.action_space = action_space
        self.reward_function = reward_function

        # Initialize environment state
        self.reset()

    def reset(self):
        """
        Reset environment to initial state with random angle of pole and position of cart.
        """
        self.state = np.array([
            np.random.uniform(-0.05, 0.05),
            0.0,
            np.random.uniform(-0.05, 0.05),
            0.0])

        self.steps_count = 0

        return self.state.copy()

    def step(self, action_idx):
        """
        Execute one step in environment.
        """
        # Get force corresponding passed action index
        force, _ = self.action_space.get_force(action_idx)

        # Get next state with model
        next_state = self.model.next_state(self.state, force)

        # Get reward: For gym_based, no need for theta; otherwise pass next_state[2]
        if self.reward_function.reward_type == 'gym_based':
            reward = self.reward_function.get_reward()  # Fixed +1 for gym_based
        else:
            reward = self.reward_function.get_reward(next_state[2])

        # Update current environment state
        self.state = next_state
        self.steps_count += 1

        # Check if next state is terminal
        terminal = self.is_terminal(next_state, max_steps=500)

        return next_state, reward, terminal

    def is_terminal(self, state, x_limit = 2.4, theta_limit = 0.20944, max_steps = None):
        """
        Determine if current state is terminal (x cross x_limit, theta cross theta_limit, maximum ).
        """
        x, _, theta, _ = state

        if max_steps is None:
            return (abs(x) > x_limit) or (abs(theta) > theta_limit)
        else:
            return (abs(x) > x_limit) or (abs(theta) > theta_limit) or (self.steps_count >= max_steps)

# %% [markdown]
# ### **Implement:** `Evaluate Trained Q-Learning Agent Method`

# %%
def evaluate_agent(environment, state_discretizer, agent, episodes_number, max_steps):
    """
    Evaluate trained agent performance without exploration.

    Parameters:
        environment: CartPoleEnvironment instance
        state_discretizer: CartPoleStateDiscretizer instance
        agent: trained QLearningAgent instance
        num_episodes: number of evaluation episodes
        max_steps: maximum steps per episode
    """
    total_rewards = []
    total_steps = []
    succesfull_episodes = 0

    for episode in range(episodes_number):
        # Reset environemnt to initial state
        state = environment.reset()
        state_discrete = state_discretizer.discretize_state(state)

        episode_reward = 0
        episode_steps = 0
        terminal = False

        # Run episode until terminal state or max steps reached
        while not terminal and episode_steps < max_steps:
            # Turn training flag off (False) -> Return action with the best Q-value
            action = agent.get_action(state_discrete, training_active=False)
            next_state, reward, terminal = environment.step(action)
            next_state_discrete = state_discretizer.discretize_state(next_state)

            # Without update of Q-table cuz full exploitation

            state_discrete = next_state_discrete
            episode_reward += reward
            episode_steps += 1

        total_rewards.append(episode_reward)
        total_steps.append(episode_steps)

        # In evaluation of agent successfull episode is one where pole is balanced for 200 steps
        if episode_steps >= max_steps:
            succesfull_episodes += 1

    return total_rewards, total_steps, succesfull_episodes

# %% [markdown]
# ### **Implement:** `Show Results and Helper Methods`

# %%
def plot_results(training_rewards, training_steps, evaluation_rewards, evaluation_steps):

    figure, axes = plt.subplots(2, 2, figsize=(12, 8))

    # 1. Training rewards
    axes[0, 0].plot(training_rewards)
    axes[0, 0].set_title("Training Rewards")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Total Reward")

    # 2. Training steps
    axes[0, 1].plot(training_steps)
    axes[0, 1].set_title("Training Steps")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Steps")

    # 3. Evaluation rewards
    axes[1, 0].plot(evaluation_rewards)
    axes[1, 0].set_title("Evaluation Rewards")
    axes[1, 0].set_xlabel("Episode")
    axes[1, 0].set_ylabel("Total Reward")

    # 4. Evaluation steps
    axes[1, 1].plot(evaluation_steps)
    axes[1, 1].set_title("Evaluation Steps")
    axes[1, 1].set_xlabel("Episode")
    axes[1, 1].set_ylabel("Steps")

    # Adjust padding between plots and show
    plt.tight_layout()
    plt.show()

# %%
def print_results(rewards, steps, episodes_num,  evaluate_flag = False, successfull_num = 0):

    print("Statistics:")
    print(f"Average reward per episode:     {np.mean(rewards):.2f}")
    print(f"Average number of steps:        {np.mean(steps):.2f}")
    print(f"Min reward per episode:         {min(rewards):.2f}")
    print(f"Min number of steps:            {min(steps):.2f}")
    print(f"Max reward per episode:         {max(rewards):.2f}")
    print(f"Max number of steps:            {max(steps):.2f}")

    if evaluate_flag:
        print(f"Number of successfull episodes: {successfull_num:.2f}")
        success_rate = (successfull_num / episodes_num) * 100
        print(f"Success rate:                   {success_rate:.2f}%")

# %%
def run_agent(environment, state_discretizer, agent, episodes_num, max_steps):

    print("Q-Learning Agent: Training starts ...")

    training_rewards, training_steps = train_agent(environment = environment,
                                                   state_discretizer = state_discretizer,
                                                   agent = agent,
                                                   episodes_number = episodes_num,
                                                   max_steps = max_steps)

    print("Q-Learning Agent: Training finished.")

    print("Q-Learning Agent: Evaluation starts ...")

    evaluation_rewards, evaluation_steps, successfull_num = evaluate_agent(environment = environment,
                                                                           state_discretizer = state_discretizer,
                                                                           agent = agent,
                                                                           episodes_number = episodes_num,
                                                                           max_steps = max_steps)
    print("Q-Learning Agent: Evaluation finished.")

    plot_results(training_rewards = training_rewards,
                 training_steps = training_steps,
                 evaluation_rewards = evaluation_rewards,
                 evaluation_steps = evaluation_steps)

    print("AGENT TRAINING")
    print_results(rewards = training_rewards,
                  steps = training_steps,
                  episodes_num = episodes_num,
                  evaluate_flag = False,
                  successfull_num = 0)

    print()

    print("AGENT EVALUATION")
    print_results(rewards = evaluation_rewards,
                  steps = evaluation_steps,
                  episodes_num = episodes_num,
                  evaluate_flag = True,
                  successfull_num = successfull_num)

# %% [markdown]
# ### **Implement:** `Main Q-Learning Agent & Fine Tuning`

# %%
config = {
    "random_seed": 42,
    "time_step": 0.02,                          # Envionment parameters
    "bins": (15, 15, 30, 30),
    "actions_type": "ternary",
    "reward_type": "gym_based",
    "episodes_train": 20000,                     # Training and evaluation constants
    "episodes_eval": 2000,
    "max_steps": 500,
    "max_force": 10.0,
    "terminal_theta": 0.20944,
    "gamma": 0.95,                              # Q-Learning hyperparameters
    "epsilon": 1.0,
    "epsilon_min": 0.01,
    "epsilon_decay": 0.9999,
    "alpha": 0.2
}

# %%
def set_seed(seed = 42):
    random.seed(seed)
    np.random.seed(seed)

# %%
def train_and_evaluate_agent(config: dict):

    set_seed(seed = config['random_seed'])

    model = CartPoleModel(T = config['time_step'])

    action_space = ActionSpace(actions_type = config['actions_type'],
                               max_force = config['max_force'])

    reward_function = RewardFunction(reward_type = config['reward_type'], alpha = 2.0,
                                     terminal_theta = config['terminal_theta'])

    environment = CartPoleEnvironment(model, action_space, reward_function)

    state_discretizer = CartPoleStateDiscretizer(bins = config['bins'])

    agent = QLearningAgent(action_size = action_space.action_num,
                           gamma = config['gamma'],
                           epsilon = config['epsilon'],
                           epsilon_min = config['epsilon_min'],
                           epsilon_decay = config['epsilon_decay'],
                           alpha = config['alpha'])

    training_rewards, training_steps = train_agent(environment, state_discretizer, agent,
                                                   episodes_number = config['episodes_train'],
                                                   max_steps = config['max_steps'])

    evaluation_rewards, evaluation_steps, success = evaluate_agent(environment, state_discretizer,
                                                                   agent,
                                                                   episodes_number = config['episodes_eval'],
                                                                   max_steps = config['max_steps'])

    return training_rewards, training_steps, evaluation_rewards, evaluation_steps, success

# %%
def compare_and_display_results(training_rewards, training_steps, evaluation_rewards, evaluation_steps, success):

    episodes_eval = len(evaluation_rewards)

    print("Performance comparison: TRAINING vs EVALUATION")

    print("--------------------------------------------------------------")
    print("| METRIC              | TRAINING   | EVALUATION | DIFFERENCE |")
    print("--------------------------------------------------------------")

    train_avg_reward = np.mean(training_rewards)
    eval_avg_reward = np.mean(evaluation_rewards)
    print(f"| Avg. Reward         | {train_avg_reward:10.2f} | {eval_avg_reward:10.2f} | {eval_avg_reward - train_avg_reward:10.2f} |")

    train_avg_steps = np.mean(training_steps)
    eval_avg_steps = np.mean(evaluation_steps)
    print(f"| Avg. Steps          | {train_avg_steps:10.2f} | {eval_avg_steps:10.2f} | {eval_avg_steps - train_avg_steps:10.2f} |")

    train_max_reward = max(training_rewards)
    eval_max_reward = max(evaluation_rewards)
    print(f"| Max. Reward         | {train_max_reward:10.2f} | {eval_max_reward:10.2f} | {eval_max_reward - train_max_reward:10.2f} |")

    train_max_steps = max(training_steps)
    eval_max_steps = max(evaluation_steps)
    print(f"| Max. Steps          | {train_max_steps:10} | {eval_max_steps:10} | {eval_max_steps - train_max_steps:10} |")

    train_std_reward = np.std(training_rewards)
    eval_std_reward = np.std(evaluation_rewards)
    print(f"| Std. Dev. Reward    | {train_std_reward:10.2f} | {eval_std_reward:10.2f} | {eval_std_reward - train_std_reward:10.2f} |")

    print("--------------------------------------------------------------")
    print(f"| Success Rate (Eval) | {'- X -':>10} | {((success / episodes_eval) * 100):.2f}%     | {'- X -':>10} |")
    print("--------------------------------------------------------------")

# %% [markdown]
# #### **Fine Tuning Process**

# %%
def run_experiment(config):
    training_rewards, training_steps, evaluation_rewards, evaluation_steps, success_rate = train_and_evaluate_agent(config = config)

    compare_and_display_results(training_rewards, training_steps, evaluation_rewards,
                                evaluation_steps, success_rate)

# %%
config = {
    "random_seed": 42,
    "time_step": 0.02,
    "bins": (6, 6, 12, 12), 
    "actions_type": "binary",
    "reward_type": "gym_based",
    "episodes_train": 5000,
    "episodes_eval": 500,
    "max_steps": 500,
    "max_force": 10.0,
    "terminal_theta": 0.20944,
    "gamma": 0.98,
    "epsilon": 1.0,
    "epsilon_min": 0.005,
    "epsilon_decay": 0.9998,
    "alpha": 0.2
}

run_experiment(config = config)
# Out:
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |      69.16 |     494.67 |     425.50 |
# | Avg. Steps          |      69.16 |     494.67 |     425.50 |
# | Max. Reward         |     500.00 |     500.00 |       0.00 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |      62.08 |      30.66 |     -31.42 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 95.60%     |      - X - |
# --------------------------------------------------------------

# %%
def hyperparameter_search(param_grid, base_config, episodes_train=5000, episodes_eval=500, max_steps=500):
    """
    Searches the hyperparameters for a Q-Learning agent and returns the best agent.

    param_grid: dict -> keys are hyperparameters, values ​​are lists of possible values
    base_config: dict -> base configuration
    episodes_train: int -> number of training episodes
    episodes_eval: int -> number of episodes to evaluate
    max_steps: int -> maximum number of steps in an episode

    return: best_config, best_score
    """
    best_config = None
    best_success_rate = -1
    best_score = None

    # All possible sets of hyperparameters (combinations)
    keys, values = zip(*param_grid.items())
    for combo in product(*values):
        
        # Create current configuration
        config = base_config.copy()
        config.update(dict(zip(keys, combo)))
        config["episodes_train"] = episodes_train
        config["episodes_eval"] = episodes_eval
        config["max_steps"] = max_steps

        print(f"Testing config: {config}")

        # Train and evaluate the agent
        training_rewards, training_steps, evaluation_rewards, evaluation_steps, success = train_and_evaluate_agent(config)

        success_rate = (success / episodes_eval) * 100
        avg_steps = np.mean(evaluation_steps)

        print(f"Success Rate: {success_rate:.2f}% | Avg Steps: {avg_steps:.2f}")

        # If it's a better agent -> remember it
        if success_rate > best_success_rate or (success_rate == best_success_rate and avg_steps > np.mean(best_score[1]) if best_score else True):
            best_success_rate = success_rate
            best_config = config
            best_score = (evaluation_rewards, evaluation_steps)

    return best_config, best_success_rate

# %%
param_grid = {
    "alpha": [0.05, 0.1, 0.2],
    "gamma": [0.95, 0.98, 0.99],
    "epsilon_decay": [0.999, 0.9995, 0.9999],
    "bins": [(6, 6, 12, 12), (8, 8, 16, 16)]
}

base_config = {
    "random_seed": 42,
    "time_step": 0.02,
    "actions_type": "binary",
    "reward_type": "gym_based",
    "epsilon": 1.0,
    "epsilon_min": 0.01,
    "max_force": 10.0,
    "terminal_theta": 0.20944
}

best_config, best_success = hyperparameter_search(param_grid, base_config)

print("\nBest configuration found:")
print(best_config)
print(f"Best Success Rate: {best_success:.2f}%")
# Out:
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.95, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 163.19
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.95, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 123.97
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.95, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.20% | Avg Steps: 210.54
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.95, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 121.94
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.95, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 278.97
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.95, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 228.02
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.98, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.80% | Avg Steps: 172.80
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.98, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 63.78
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.98, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 289.95
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.98, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 148.70
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.98, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 208.13
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.98, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 99.80% | Avg Steps: 499.83
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.99, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.20% | Avg Steps: 113.77
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.99, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 6.60% | Avg Steps: 96.82
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.99, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 238.74
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.99, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 140.18
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.99, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 8.80% | Avg Steps: 306.28
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.99, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 61.20% | Avg Steps: 426.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.95, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 134.65
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.95, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 1.00% | Avg Steps: 157.50
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.95, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 166.56
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.95, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 98.88
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.95, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.95, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 240.88
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.98, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 177.31
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.98, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 1.20% | Avg Steps: 173.20
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.98, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 121.70
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.98, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.60% | Avg Steps: 117.18
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.98, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 73.40% | Avg Steps: 458.11
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.98, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 143.63
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.99, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 213.86
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.99, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 131.31
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.99, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 130.08
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.99, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 3.00% | Avg Steps: 248.64
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.99, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 343.10
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.99, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 1.80% | Avg Steps: 284.72
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.95, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 116.44
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.95, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 118.87
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.95, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 142.49
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.95, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 1.60% | Avg Steps: 192.23
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.95, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 280.30
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.95, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 1.40% | Avg Steps: 201.06
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.98, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 137.10
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.98, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.20% | Avg Steps: 152.34
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.98, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 191.27
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.98, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 70.80% | Avg Steps: 447.25
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.98, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 49.40% | Avg Steps: 329.10
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.98, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 4.60% | Avg Steps: 236.15
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.99, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 11.00% | Avg Steps: 293.61
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.99, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 150.46
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.99, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 3.00% | Avg Steps: 182.61
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.99, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 58.60% | Avg Steps: 417.69
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.99, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.40% | Avg Steps: 189.60
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.99, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 289.97
#
# Best configuration found:
# {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'gym_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.95, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Best Success Rate: 100.00%

# %%
param_grid = {
    "alpha": [0.05, 0.1, 0.2],
    "gamma": [0.95, 0.98, 0.99],
    "epsilon_decay": [0.999, 0.9995, 0.9999],
    "bins": [(6, 6, 12, 12), (8, 8, 16, 16)]
}

base_config = {
    "random_seed": 42,
    "time_step": 0.02,
    "actions_type": "binary",
    "reward_type": "angle_based",
    "epsilon": 1.0,
    "epsilon_min": 0.01,
    "max_force": 10.0,
    "terminal_theta": 0.20944
}

best_config, best_success = hyperparameter_search(param_grid, base_config)

print("\nBest configuration found:")
print(best_config)
print(f"Best Success Rate: {best_success:.2f}%")
# Out:
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.95, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 61.40% | Avg Steps: 472.80
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.95, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.95, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.95, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.95, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 8.20% | Avg Steps: 288.03
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.95, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.98, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.98, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.98, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.40% | Avg Steps: 367.92
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.98, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 48.40% | Avg Steps: 446.14
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.98, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 12.20% | Avg Steps: 382.34
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.98, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 34.20% | Avg Steps: 367.08
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.99, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.99, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.99, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 42.00% | Avg Steps: 439.16
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.99, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.99, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 7.60% | Avg Steps: 320.55
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.99, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.95, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.95, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 41.40% | Avg Steps: 440.66
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.95, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 41.80% | Avg Steps: 435.35
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.95, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 84.20% | Avg Steps: 495.11
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.95, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.20% | Avg Steps: 267.68
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.95, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.20% | Avg Steps: 283.56
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.98, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.98, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.98, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.98, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 89.60% | Avg Steps: 494.32
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.98, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 35.80% | Avg Steps: 382.91
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.98, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 34.80% | Avg Steps: 354.74
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.99, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.99, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.99, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.99, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.99, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 259.88
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.1, 'gamma': 0.99, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.95, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.95, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.95, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 33.20% | Avg Steps: 426.97
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.95, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.95, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 54.20% | Avg Steps: 414.18
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.95, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.20% | Avg Steps: 297.51
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.98, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.98, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.98, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 77.60% | Avg Steps: 485.12
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.98, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.98, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 0.00% | Avg Steps: 283.38
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.98, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 98.40% | Avg Steps: 498.18
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.99, 'epsilon_decay': 0.999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.99, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.99, 'epsilon_decay': 0.9995, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.99, 'epsilon_decay': 0.9995, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 100.00% | Avg Steps: 500.00
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.99, 'epsilon_decay': 0.9999, 'bins': (6, 6, 12, 12), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 38.60% | Avg Steps: 355.91
# Testing config: {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.2, 'gamma': 0.99, 'epsilon_decay': 0.9999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Success Rate: 38.60% | Avg Steps: 368.03
#
# Best configuration found:
# {'random_seed': 42, 'time_step': 0.02, 'actions_type': 'binary', 'reward_type': 'angle_based', 'epsilon': 1.0, 'epsilon_min': 0.01, 'max_force': 10.0, 'terminal_theta': 0.20944, 'alpha': 0.05, 'gamma': 0.95, 'epsilon_decay': 0.999, 'bins': (8, 8, 16, 16), 'episodes_train': 5000, 'episodes_eval': 500, 'max_steps': 500}
# Best Success Rate: 100.00%

# %%
config = {
    "random_seed": 42,
    "time_step": 0.02,
    "bins": (6, 6, 12, 12), 
    "actions_type": "binary",
    "reward_type": "gym_based",
    "episodes_train": 5000,
    "episodes_eval": 500,
    "max_steps": 500,
    "max_force": 10.0,
    "terminal_theta": 0.20944,
    "gamma": 0.95,
    "epsilon": 1.0,
    "epsilon_min": 0.01,
    "epsilon_decay": 0.9999,
    "alpha": 0.1
}

run_experiment(config = config)
# Out:
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |      39.00 |     500.00 |     461.00 |
# | Avg. Steps          |      39.00 |     500.00 |     461.00 |
# | Max. Reward         |     285.00 |     500.00 |     215.00 |
# | Max. Steps          |        285 |        500 |        215 |
# | Std. Dev. Reward    |      30.63 |       0.00 |     -30.63 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 100.00%     |      - X - |
# --------------------------------------------------------------

# %%
for seed in [0, 1, 2, 7, 13, 21, 42, 99, 123, 2025]:
    config["random_seed"] = seed
    print(f"\n===== SEED = {seed} =====")
    run_experiment(config)

# %%
config = {
    "random_seed": 42,
    "time_step": 0.02,              
    "bins": (8, 8, 16, 16),
    "actions_type": "binary",
    "reward_type": "angle_based",
    "episodes_train": 20000,
    "episodes_eval": 2000,
    "max_steps": 500,
    "max_force": 10.0,
    "terminal_theta": 0.20944,
    "gamma": 0.95,
    "epsilon": 1.0,
    "epsilon_min": 0.05,
    "epsilon_decay": 0.999,
    "alpha": 0.1        
}

run_experiment(config = config)
# Out:
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |    -235.62 |    -114.73 |     120.89 |
# | Avg. Steps          |     460.12 |     498.18 |      38.07 |
# | Max. Reward         |     -33.01 |     -60.48 |     -27.48 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |     312.98 |     102.83 |    -210.15 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 90.00%     |      - X - |
# --------------------------------------------------------------

# %%
config = {
    "random_seed": 42,
    "time_step": 0.02,              
    "bins": (10, 10, 18, 18),
    "actions_type": "binary",
    "reward_type": "angle_based",
    "episodes_train": 20000,
    "episodes_eval": 2000, 
    "max_steps": 500,
    "max_force": 10.0,
    "terminal_theta": 0.20944,
    "gamma": 0.98,
    "epsilon": 1.0,
    "epsilon_min": 0.05, 
    "epsilon_decay": 0.999,
    "alpha": 0.1                  
}

run_experiment(config = config)
# Out:
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |    -264.08 |     -66.70 |     197.39 |
# | Avg. Steps          |     452.66 |     500.00 |      47.34 |
# | Max. Reward         |     -42.56 |     -43.96 |      -1.40 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |     336.69 |      10.10 |    -326.59 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 100.00%     |      - X - |
# --------------------------------------------------------------

# %%
for seed in [0, 1, 2, 7, 13, 21, 42, 99, 123, 2025]:
    config["random_seed"] = seed
    print(f"\n===== SEED = {seed} =====")
    run_experiment(config)
# Out:
# ===== SEED = 0 =====
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |    -265.06 |     -68.48 |     196.59 |
# | Avg. Steps          |     453.35 |     500.00 |      46.65 |
# | Max. Reward         |     -41.33 |     -44.41 |      -3.07 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |     333.11 |      10.87 |    -322.25 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 100.00%     |      - X - |
# --------------------------------------------------------------
#
# ===== SEED = 1 =====
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |    -263.35 |     -71.13 |     192.21 |
# | Avg. Steps          |     452.89 |     500.00 |      47.11 |
# | Max. Reward         |     -33.96 |     -44.01 |     -10.05 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |     335.61 |      10.43 |    -325.18 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 100.00%     |      - X - |
# --------------------------------------------------------------
#
# ===== SEED = 2 =====
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |    -266.60 |     -82.48 |     184.12 |
# | Avg. Steps          |     452.89 |     500.00 |      47.11 |
# | Max. Reward         |     -40.19 |     -44.22 |      -4.03 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |     336.11 |      48.35 |    -287.75 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 99.80%     |      - X - |
# --------------------------------------------------------------
#
# ===== SEED = 7 =====
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |    -264.82 |    -104.11 |     160.72 |
# | Avg. Steps          |     452.35 |     499.96 |      47.61 |
# | Max. Reward         |     -29.03 |     -49.42 |     -20.39 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |     332.26 |      57.26 |    -275.00 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 99.75%     |      - X - |
# --------------------------------------------------------------
#
# ===== SEED = 13 =====
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |    -266.06 |     -67.56 |     198.50 |
# | Avg. Steps          |     452.82 |     500.00 |      47.18 |
# | Max. Reward         |     -42.37 |     -41.36 |       1.02 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |     333.86 |      10.33 |    -323.53 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 100.00%     |      - X - |
# --------------------------------------------------------------
#
# ===== SEED = 21 =====
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |    -267.46 |     -68.52 |     198.94 |
# | Avg. Steps          |     452.21 |     500.00 |      47.79 |
# | Max. Reward         |     -31.42 |     -41.30 |      -9.88 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |     340.07 |      10.74 |    -329.33 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 100.00%     |      - X - |
# --------------------------------------------------------------
#
# ===== SEED = 42 =====
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |    -264.08 |     -66.70 |     197.39 |
# | Avg. Steps          |     452.66 |     500.00 |      47.34 |
# | Max. Reward         |     -42.56 |     -43.96 |      -1.40 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |     336.69 |      10.10 |    -326.59 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 100.00%     |      - X - |
# --------------------------------------------------------------
#
# ===== SEED = 99 =====
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |    -266.01 |     -71.55 |     194.46 |
# | Avg. Steps          |     452.52 |     500.00 |      47.48 |
# | Max. Reward         |     -36.18 |     -42.90 |      -6.72 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |     334.42 |      11.66 |    -322.76 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 100.00%     |      - X - |
# --------------------------------------------------------------
#
# ===== SEED = 123 =====
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |    -266.36 |    -159.93 |     106.42 |
# | Avg. Steps          |     452.20 |     500.00 |      47.80 |
# | Max. Reward         |     -38.40 |     -93.03 |     -54.63 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |     335.55 |      23.79 |    -311.76 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 100.00%     |      - X - |
# --------------------------------------------------------------
#
# ===== SEED = 2025 =====
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |    -264.43 |     -68.11 |     196.32 |
# | Avg. Steps          |     452.66 |     500.00 |      47.34 |
# | Max. Reward         |     -40.92 |     -45.85 |      -4.93 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |     331.32 |      10.56 |    -320.77 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 100.00%     |      - X - |
# --------------------------------------------------------------

# %% [markdown]
# ### **Final Q-Learning Agent Configuration**

# %%
config = {
    "random_seed": 42,              
    "time_step": 0.02,              
    "bins": (10, 10, 18, 18),       
    "actions_type": "binary",       
    "reward_type": "angle_based",
    "episodes_train": 20000,
    "episodes_eval": 2000,
    "max_steps": 500,
    "max_force": 10.0,
    "terminal_theta": 0.20944,
    "gamma": 0.98,
    "epsilon": 1.0,
    "epsilon_min": 0.05,
    "epsilon_decay": 0.999, 
    "alpha": 0.1
}

run_experiment(config = config)

# %% [markdown]
# ### **Note:**

# %% [markdown]
# - The file `CartPole-Project` contains documented results of testing and fine-tuning of the Q-Learning Agent.
# - In the same file, the Q-Learning Agent was evaluated by measuring the maximum number of steps reached during each episode. Here are results (can be found in section **Test unlimited steps in evaluation**):
# ```terminal
# Performance comparison: TRAINING vs EVALUATION
# --------------------------------------------------------------
# | METRIC              | TRAINING   | EVALUATION | DIFFERENCE |
# --------------------------------------------------------------
# | Avg. Reward         |    -264.08 |     -66.70 |     197.39 |
# | Avg. Steps          |     452.66 |     500.00 |      47.34 |
# | Max. Reward         |     -42.56 |     -43.96 |      -1.40 |
# | Max. Steps          |        500 |        500 |          0 |
# | Std. Dev. Reward    |     336.69 |      10.10 |    -326.59 |
# --------------------------------------------------------------
# | Success Rate (Eval) |      - X - | 100.00%     |      - X - |
# --------------------------------------------------------------
#
# === Evaluacija agenta bez ograničenja koraka (5 epizoda) ===
#   Epizoda 1: 2467 koraka
#   Epizoda 2: 2420 koraka
#   Epizoda 3: 2483 koraka
#   Epizoda 4: 2368 koraka
#   Epizoda 5: 2426 koraka
#
# Statistike neograničene evaluacije:
# Prosečan broj koraka:    2432.80
# Minimalan broj koraka:   2368
# Maksimalan broj koraka:  2483
# Ukupno koraka:           12164
# ```
